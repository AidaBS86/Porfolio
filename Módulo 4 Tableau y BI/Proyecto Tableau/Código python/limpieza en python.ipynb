# %%
import pandas as pd
import matplotlib as plt

# %%
def eda (df):
    print('Número de filas:')
    display(df.shape[0])
    print('----------------------------------------------------------------------------------')
    print('Número de columnas:')
    display(df.shape[1])
    print('----------------------------------------------------------------------------------')
    print('Información dataframe:')
    display(df.info())
    print('----------------------------------------------------------------------------------')
    print('Nombre de las columnas:')
    display(df.columns)
    print('----------------------------------------------------------------------------------')
    columnas_num = df.select_dtypes(include='number')
    if not columnas_num.empty:
        print('Descripción datos numéricos:')
        display(columnas_num.describe().T)
    else:
        print('No hay datos de tipo numérico')
    print('----------------------------------------------------------------------------------')
    columnas_str = df.select_dtypes(include='object')
    if not columnas_str.empty:
        print('Descripción datos string:')
        display(columnas_str.describe().T)
    else:
        print('No hay datos de tipo string')
    print('----------------------------------------------------------------------------------')
    columnas_fecha = df.select_dtypes(include='datetime')
    if not columnas_fecha.empty:
        print('Descripción datos fechas:')
        display(columnas_fecha.describe().T)
    else:
        print('No hay datos de tipo fechas')
    print('----------------------------------------------------------------------------------')
    print('Cuantos datos únicos hay por columna:')
    display(df.nunique())
    print('----------------------------------------------------------------------------------')
    for col in df.columns:
        print(f'Datos unicos de la {col}:\n {df[col].value_counts()}\n')
    print('----------------------------------------------------------------------------------')
    print('Cuantos datos nulos hay:')
    display(df.isnull().sum())
    print('----------------------------------------------------------------------------------')
    porcentajes_nulos = df.isnull().mean() * 100
    cols_numericas = df.select_dtypes(include=['number']).columns
    cols_categoricas = df.select_dtypes(include=['object', 'category']).columns
    cols_fechas = df.select_dtypes(include=['datetime']).columns
    nulos_numericas = porcentajes_nulos[cols_numericas]
    nulos_categoricas = porcentajes_nulos[cols_categoricas]
    nulos_fechas = porcentajes_nulos[cols_fechas]
    if (porcentajes_nulos > 0).any():
        if (nulos_numericas > 0).any():
            print('Porcentajes de nulos en columnas numéricas:')
            print(nulos_numericas.sort_values(ascending=False))
        else:
            print('No hay nulos en columnas numéricas.')
            print('----------------------------------------------------------------------------------')
        if (nulos_categoricas > 0).any():
            print('\nPorcentajes de nulos en columnas categóricas:')
            print(nulos_categoricas.sort_values(ascending=False))
        else:
            print('No hay nulos en columnas categóricas.')
            print('----------------------------------------------------------------------------------')
        if (nulos_fechas > 0).any():
            print('\nPorcentajes de nulos en columnas de fechas:')
            print(nulos_fechas.sort_values(ascending=False))
        else:
            print('No hay nulos en columnas de fechas.')
    else:
        pass
    print('----------------------------------------------------------------------------------')
    cantid_duplicadas = df.duplicated().sum()
    print(f'Cantidad de duplicados: {cantid_duplicadas}')
    if cantid_duplicadas >0:
        print('Primeros duplicados:')
        display(df[df.duplicated()].head(3))
    else:
        print('No hay duplicados')
    print('------------------------------------------------------------------------------------')
    print('Columnas constantes (solo 1 valor único):')
    constantes = df.columns[df.nunique() <= 1]
    if len(constantes) > 0:
        print(f'{len(constantes)} columnas con 1 valor único:')
        display(constantes)
    else:
        print('No hay columnas constantes')
    print('------------------------------------------------------------------------------------')

# %%
df = pd.read_csv('mental_health_dataset.csv', index_col=False)
df
# Out:
#       age      gender employment_status work_environment  \
# 0      56        Male          Employed          On-site
# 1      46      Female           Student          On-site
# 2      32      Female          Employed          On-site
# 3      60  Non-binary     Self-employed          On-site
# 4      25      Female     Self-employed          On-site
# ...   ...         ...               ...              ...
# 9995   34      Female          Employed          On-site
# 9996   47        Male          Employed          On-site
# 9997   56      Female          Employed          On-site
# 9998   24        Male          Employed          On-site
# 9999   44        Male        Unemployed           Remote
#
#      mental_health_history seeks_treatment  stress_level  sleep_hours  \
# 0                      Yes             Yes             6          6.2
# 1                       No             Yes            10          9.0
# ...

# %%
df1 = pd.read_excel('Mental health Depression disorder Data.xlsx', index_col=False)
df1
# Out:
#            Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
df1.drop('Code', axis=1, inplace=True)
df1.head(1)
# Out:
#         Entity  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0  Afghanistan  1990            0.16056              0.697779
#
#    Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0              0.101855                4.82883                1.677082
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404

# %%
df2 = pd.read_csv('Mental Health Dataset.csv', index_col=False)
df2
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
def extraer_año(df, columna_fecha):
    """
    Extrae el año de una columna de tipo fecha+hora y reemplaza los valores en la misma columna.

    Parámetros:
    - df: DataFrame de pandas
    - columna_fecha: nombre de la columna (string) que contiene datos de fecha+hora

    Retorna:
    - El DataFrame con la columna modificada (solo el año)
    """
    df2['Timestamp'] = pd.to_datetime(df2['Timestamp'], errors='coerce')  # Convertir a datetime
    df2['Timestamp'] = df2['Timestamp'].dt.year  # Extraer el año
    return df2

# %%
extraer_año(df2, 'Timestamp')
df2.head(3)
# Out:
#    Timestamp  Gender        Country Occupation self_employed family_history  \
# 0       2014  Female  United States  Corporate           NaN             No
# 1       2014  Female  United States  Corporate           NaN            Yes
# 2       2014  Female  United States  Corporate           NaN            Yes
#
#   treatment Days_Indoors Growing_Stress Changes_Habits Mental_Health_History  \
# 0       Yes    1-14 days            Yes             No                   Yes
# 1       Yes    1-14 days            Yes             No                   Yes
# 2       Yes    1-14 days            Yes             No                   Yes
#
#   Mood_Swings Coping_Struggles Work_Interest Social_Weakness  \
# 0      Medium               No            No             Yes
# 1      Medium               No            No             Yes
# 2      Medium               No            No             Yes
#
#   mental_health_interview care_options
# 0                      No     Not sure
# ...

# %%
df2.rename(columns={'Timestamp': 'Year'}, inplace=True)
df2.head(1)
# Out:
#    Year  Gender        Country Occupation self_employed family_history  \
# 0  2014  Female  United States  Corporate           NaN             No
#
#   treatment Days_Indoors Growing_Stress Changes_Habits Mental_Health_History  \
# 0       Yes    1-14 days            Yes             No                   Yes
#
#   Mood_Swings Coping_Struggles Work_Interest Social_Weakness  \
# 0      Medium               No            No             Yes
#
#   mental_health_interview care_options
# 0                      No     Not sure

# %%
eda(df2)
# Out:
# Número de filas:
# 292364
# ----------------------------------------------------------------------------------
# Número de columnas:
# 17
# ----------------------------------------------------------------------------------
# Información dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Year                     292364 non-null  int32
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            287162 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
def imputacion_nulos(df):
    # Imputación de columnas categóricas:
    columnas_categóricas_con_nulos = df[df.columns[df.isnull().any()]].select_dtypes(include = "O").columns
    for col in columnas_categóricas_con_nulos:
        nulos = df[col].isnull().sum()
        total = len(df)
        porcentaje_nulos = nulos / total

        if porcentaje_nulos > 0.20:
            # Si hay más del 20% de nulos; rellenar con "Desconocido"
            df[col] = df[col].fillna("Desconocido")
            print(f"{col} se va a imputar con Desconocido")
        else:
            # Menos del 20% de nulos
            valores = df[col].value_counts(dropna=True)
            if len(valores) >= 2:
                # Calcular diferencia porcentual entre los dos más frecuentes
                primero = valores.iloc[0]
                segundo = valores.iloc[1]
                diferencia = (primero - segundo) / total

                if diferencia > 0.20:
                    # Si la diferencia entre los dos más comunes > 20% → usar moda
                    moda = valores.idxmax() #es lo mismo que decirle la moda = df[col].mode[0]
                    df[col] = df[col].fillna(moda)
                    print(f"{col} se va a imputar con la moda")
                else:
                    # Si no → usar "Desconocido"
                    df[col] = df[col].fillna("Desconocido")
                    print(f"{col} se va a imputar con Desconocido")
            else:
                moda = valores.idxmax() #es lo mismo que decirle la moda = df[col].mode[0]
                df[col] = df[col].fillna(moda)
                print(f"{col} se va a imputar con la moda")

# %%
imputacion_nulos(df2)
# Out:
# self_employed se va a imputar con la moda

# %%
df2.isnull().sum()
# Out:
# Year                       0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
df2 = df2.drop_duplicates()
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
def limpieza(df):
    columnas_num = df.select_dtypes(include=['number']).columns
    for col in columnas_num:
        df[col] = df[col].astype(str)
        df[col] = df[col].str.replace('.', ',')
    df.columns = [col.replace('_', ' ').title() for col in df.columns]
    return df

# %%
limpieza(df2)
df2
# Out:
# C:\Users\AIDA\AppData\Local\Temp\ipykernel_11592\424931435.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str)
# C:\Users\AIDA\AppData\Local\Temp\ipykernel_11592\424931435.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.replace('.', ',')
#         Year  Gender        Country Occupation Self Employed Family History  \
# 0       2014  Female  United States  Corporate            No             No
# ...

# %%
limpieza(df)
df
# Out:
#      Age      Gender Employment Status Work Environment Mental Health History  \
# 0     56        Male          Employed          On-site                   Yes
# 1     46      Female           Student          On-site                    No
# 2     32      Female          Employed          On-site                   Yes
# 3     60  Non-binary     Self-employed          On-site                    No
# 4     25      Female     Self-employed          On-site                   Yes
# ...   ..         ...               ...              ...                   ...
# 9995  34      Female          Employed          On-site                   Yes
# 9996  47        Male          Employed          On-site                   Yes
# 9997  56      Female          Employed          On-site                   Yes
# 9998  24        Male          Employed          On-site                   Yes
# 9999  44        Male        Unemployed           Remote                    No
#
# ...

# %%
limpieza(df1)
df1
# Out:
#            Entity  Year Schizophrenia (%) Bipolar Disorder (%)  \
# 0     Afghanistan  1990    0,160559542157       0,697779384535
# 1     Afghanistan  1991     0,16031189863       0,697960594942
# 2     Afghanistan  1992    0,160134822429       0,698106968899
# 3     Afghanistan  1993    0,160037391188       0,698256934369
# 4     Afghanistan  1994    0,160022297338        0,69846911816
# ...           ...   ...               ...                  ...
# 6463     Zimbabwe  2013    0,155669694963       0,607992596281
# 6464     Zimbabwe  2014    0,155992630517       0,608610399716
# 6465     Zimbabwe  2015    0,156465117257       0,609362667682
# 6466     Zimbabwe  2016     0,15711079947    0,610234233138999
# 6467     Zimbabwe  2017    0,157963235821       0,611242389594
#
#      Eating Disorders (%) Anxiety Disorders (%) Drug Use Disorders (%)  \
# 0          0,101854863459      4,82882970499999          1,67708194479
# ...

# %%
estudio_probabilidades_enfermedad_mental = df

# %%
habitos_salud_mental = df2

# %%
estadisticas_trastornos_mentales = df1

# %%
paises_filtrados = [
    'Australia', 'Belgium', 'Bosnia and Herzegovina', 'Brazil', 'Canada',
    'Colombia', 'Costa Rica', 'Croatia', 'Czech Republic', 'Denmark',
    'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'India', 'Ireland',
    'Israel', 'Italy', 'Mexico', 'Moldova', 'Netherlands', 'New Zealand',
    'Nigeria', 'Philippines', 'Poland', 'Portugal', 'Russia', 'Singapore',
    'South Africa', 'Sweden', 'Switzerland', 'Thailand', 'United Kingdom',
    'United States']

df_filtrado = estadisticas_trastornos_mentales[estadisticas_trastornos_mentales['Entity'].isin(paises_filtrados)].copy()

estadisticas_trastornos_mentales = df_filtrado

# %%
continentes = {
    # Europa
    'Belgium': 'Europa',
    'Bosnia and Herzegovina': 'Europa',
    'Croatia': 'Europa',
    'Czech Republic': 'Europa',
    'Denmark': 'Europa',
    'Finland': 'Europa',
    'France': 'Europa',
    'Georgia': 'Europa',
    'Germany': 'Europa',
    'Greece': 'Europa',
    'Ireland': 'Europa',
    'Italy': 'Europa',
    'Moldova': 'Europa',
    'Netherlands': 'Europa',
    'Poland': 'Europa',
    'Portugal': 'Europa',
    'Russia': 'Europa',
    'Sweden': 'Europa',
    'Switzerland': 'Europa',
    'United Kingdom': 'Europa',

    # América
    'Brazil': 'América',
    'Canada': 'América',
    'Colombia': 'América',
    'Costa Rica': 'América',
    'Mexico': 'América',
    'United States': 'América',

    # Oceanía
    'Australia': 'Oceanía',
    'New Zealand': 'Oceanía',

    # África
    'Nigeria': 'África',
    'South Africa': 'África',

    # Asia
    'Philippines': 'Asia',
    'India': 'Asia',
    'Israel': 'Asia',
    'Singapore': 'Asia',
    'Thailand': 'Asia',
}

# %%
estadisticas_trastornos_mentales['Continent'] = estadisticas_trastornos_mentales['Entity'].map(continentes)

# %%
estadisticas_trastornos_mentales.head(3)
# Out:
#         Entity  Year  Schizophrenia (%) Bipolar Disorder (%)  \
# 308  Australia  1990  0,360488563758999        1,12913444698
# 309  Australia  1991      0,36119568201        1,13264691281
# 310  Australia  1992     0,361892513407        1,13593554244
#
#     Eating Disorders (%) Anxiety Disorders (%) Drug Use Disorders (%)  \
# 308       0,700090525224         6,52529436951          2,13323614922
# 309       0,704108748089      6,51996827821999          2,18589310599
# 310       0,708000817574         6,51366330752           2,2350804112
#
#     Depression (%) Alcohol Use Disorders (%) Continent
# 308  4,62118658828          1,35291016420999   Oceanía
# 309  4,67193287901             1,39299745608   Oceanía
# 310  4,71541226158             1,43015792333   Oceanía

# %%
habitos_salud_mental['Continent'] = habitos_salud_mental['Country'].map(continentes)
# Out:
# C:\Users\AIDA\AppData\Local\Temp\ipykernel_11592\1551448268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   habitos_salud_mental['Continent'] = habitos_salud_mental['Country'].map(continentes)

# %%
habitos_salud_mental.head(3)
# Out:
#    Year  Gender        Country Occupation Self Employed Family History  \
# 0  2014  Female  United States  Corporate            No             No
# 1  2014  Female  United States  Corporate            No            Yes
# 2  2014  Female  United States  Corporate            No            Yes
#
#   Treatment Days Indoors Growing Stress Changes Habits Mental Health History  \
# 0       Yes    1-14 days            Yes             No                   Yes
# 1       Yes    1-14 days            Yes             No                   Yes
# 2       Yes    1-14 days            Yes             No                   Yes
#
#   Mood Swings Coping Struggles Work Interest Social Weakness  \
# 0      Medium               No            No             Yes
# 1      Medium               No            No             Yes
# 2      Medium               No            No             Yes
#
#   Mental Health Interview Care Options Continent
# 0                      No     Not sure   América
# ...

# %%
df_largo = estadisticas_trastornos_mentales.melt(
    id_vars=['Entity', 'Year', 'Continent'],
    var_name='Disorder',
    value_name='Percentage'
)

# Opcional: quitar el símbolo %
df_largo['Disorder'] = df_largo['Disorder'].str.replace('%', '').str.replace('(', '').str.replace(')', '')

# %%
df_largo
# Out:
#              Entity  Year Continent                Disorder         Percentage
# 0         Australia  1990   Oceanía          Schizophrenia   0,360488563758999
# 1         Australia  1991   Oceanía          Schizophrenia       0,36119568201
# 2         Australia  1992   Oceanía          Schizophrenia      0,361892513407
# 3         Australia  1993   Oceanía          Schizophrenia      0,362523972112
# 4         Australia  1994   Oceanía          Schizophrenia      0,363000615429
# ...             ...   ...       ...                     ...                ...
# 6855  United States  2013   América  Alcohol Use Disorders       2,00581427099
# 6856  United States  2014   América  Alcohol Use Disorders       2,01134506373
# 6857  United States  2015   América  Alcohol Use Disorders       2,01873831093
# 6858  United States  2016   América  Alcohol Use Disorders       2,02826285677
# 6859  United States  2017   América  Alcohol Use Disorders       2,04008689286
#
# [6860 rows x 5 columns]

# %%
estadisticas_trastornos_mentales.rename(columns={'Entity': 'Country'}, inplace=True)

# %%
df_largo.rename(columns={'Entity': 'Country'}, inplace=True)

# %%
estudio_probabilidades_enfermedad_mental.to_csv('estudio probabilidades enfermedad mental.csv', index=False)

# %%
estadisticas_trastornos_mentales.to_csv('estadisticas trastornos mentales.csv', index=False)

# %%
habitos_salud_mental.to_csv('habitos salud mental.csv', index=False)

# %%
df_largo.to_csv('estadisticas trastornos mentales modificado.csv', index=False)
