# %% [markdown]
# # 🐾 Juego de Preguntas sobre Animales
#
# Este juego tipo test pone a prueba tus conocimientos sobre animales.
#
# - Cada pregunta tiene 4 opciones (A, B, C, D)
# - Solo una respuesta es correcta
# - El juego termina cuando:
#   - Acumulas **5 aciertos** (ganas)
#   - Acumulas **3 errores** (pierdes)

# %%
import random
# Lista de preguntas
preguntas = [
    {
        "pregunta": "¿Cuál de estos animales es un mamífero?",
        "opciones": {"A": "Pingüino", "B": "Delfín", "C": "Tiburón", "D": "Cocodrilo"},
        "respuesta_correcta": "B"
    },
    {
        "pregunta": "¿Qué animal tiene la lengua más larga en proporción a su cuerpo?",
        "opciones": {"A": "Jirafa", "B": "Camaleón", "C": "Oso hormiguero", "D": "Murciélago"},
        "respuesta_correcta": "B"
    },
    {
        "pregunta": "¿Cuál de estos animales pone huevos?",
        "opciones": {"A": "Gato", "B": "Perro", "C": "Gallina", "D": "Caballo"},
        "respuesta_correcta": "C"
    },
    {
        "pregunta": "¿Qué animal es conocido por su memoria?",
        "opciones": {"A": "Elefante", "B": "Cebra", "C": "Ratón", "D": "Tortuga"},
        "respuesta_correcta": "A"
    },
    {
        "pregunta": "¿Cuál es el único mamífero capaz de volar?",
        "opciones": {"A": "Pato", "B": "Murciélago", "C": "Avestruz", "D": "Gaviota"},
        "respuesta_correcta": "B"
    },
    {
        "pregunta": "¿Qué animal puede cambiar de color para camuflarse?",
        "opciones": {"A": "Tiburón", "B": "Pulpo", "C": "Camaleón", "D": "Gato"},
        "respuesta_correcta": "C"
    },
    {
        "pregunta": "¿Cuál de estos animales es un reptil?",
        "opciones": {"A": "Rana", "B": "Serpiente", "C": "Pingüino", "D": "Ballena"},
        "respuesta_correcta": "B"
    },
    {
        "pregunta": "¿Qué método usa el delfín para ubicarse?",
        "opciones": {"A": "Olfato", "B": "Magnetorrecepción", "C": "Ecolocalización", "D": "Corrientes marinas"},
        "respuesta_correcta": "C"
    },
    {
        "pregunta": "¿Qué animal duerme de pie?",
        "opciones": {"A": "Gato", "B": "Caballo", "C": "Loro", "D": "Oso"},
        "respuesta_correcta": "B"
    },
    {
        "pregunta": "¿Cuál de estos animales puede reproducirse por partenogénesis (sin necesidad de macho)?",
        "opciones": {"A": "Tortuga", "B": "Tiburón", "C": "Camaleón", "D": "Cebra"},
        "respuesta_correcta": "B"
    }
]
#Inicio bucle principal
jugar = True
inicio = input("¡Bienvenida al Juego de Preguntas Generales sobre Animales! ¿Quieres empezar? (S/N): ").upper().strip()
if inicio not in ["S", "N"]:
    inicio = input("Introduce una respuesta válida (S/N): ").upper().strip()
else:
    pass

while jugar:
    #Bienvenida
    if inicio == "S":
        print("¡Empezamos!")
        # Variables de seguimiento
        aciertos = 0
        errores = 0
        preguntas_hechas = []
        # Bucle del juego
        while aciertos < 5 and errores < 3:
            pregunta = random.choice(preguntas)
            if pregunta in preguntas_hechas:
                continue  # Saltar si ya fue hecha
            preguntas_hechas.append(pregunta)
            print(pregunta["pregunta"])
            for letra, opcion in pregunta["opciones"].items():
                print(f"  {letra}) {opcion}")
            respuesta = input("Tu respuesta (A, B, C o D): ").upper().strip()
            while respuesta not in ["A", "B", "C", "D"]:
                respuesta = input("Introduce una respuesta válida (A, B, C o D): ").upper().strip()                
            if respuesta == pregunta["respuesta_correcta"]:
                aciertos += 1
                print("✅: ¡Correcto!")
            else:
                errores += 1
                correcta = pregunta["respuesta_correcta"]
                print(f"❌: Incorrecto. La respuesta correcta era {correcta}) {pregunta['opciones'][correcta]}")                         
            print(f"Aciertos: {aciertos} | Errores: {errores} | Respondidas: {len(preguntas_hechas)}\n")
        # Resultado final
        if aciertos == 5:
            print("🏆: ¡Has ganado!")
        elif errores == 3:
            print("💀: Has perdido. Inténtalo de nuevo.")
    else:
        print("Nos vemos en la próxima!")
        break
     # Volver a jugar
    jugar_otra_vez = input("¿Quieres volver a jugar? (S/N): ").upper().strip()
    while jugar_otra_vez not in ["S", "N"]:
        jugar_otra_vez = input("Introduce una respuesta válida (S/N): ").upper().strip()
    if jugar_otra_vez == "N":
        print("¡Gracias por jugar! ¡Hasta la próxima!")
        jugar = False
# Out:
# ¡Empezamos!
# ¿Qué animal tiene la lengua más larga en proporción a su cuerpo?
#   A) Jirafa
#   B) Camaleón
#   C) Oso hormiguero
#   D) Murciélago
# ❌: Incorrecto. La respuesta correcta era B) Camaleón
# Aciertos: 0 | Errores: 1 | Respondidas: 1
#
# ¿Qué método usa el delfín para ubicarse?
#   A) Olfato
#   B) Magnetorrecepción
#   C) Ecolocalización
#   D) Corrientes marinas
# ❌: Incorrecto. La respuesta correcta era C) Ecolocalización
# Aciertos: 0 | Errores: 2 | Respondidas: 2
#
# ¿Cuál de estos animales pone huevos?
#   A) Gato
#   B) Perro
#   C) Gallina
#   D) Caballo
# ✅: ¡Correcto!
# Aciertos: 1 | Errores: 2 | Respondidas: 3
#
# ¿Cuál de estos animales puede reproducirse por partenogénesis (sin necesidad de macho)?
#   A) Tortuga
#   B) Tiburón
#   C) Camaleón
#   D) Cebra
# ❌: Incorrecto. La respuesta correcta era B) Tiburón
# Aciertos: 1 | Errores: 3 | Respondidas: 4
#
# 💀: Has perdido. Inténtalo de nuevo.
# ¡Gracias por jugar! ¡Hasta la próxima!
