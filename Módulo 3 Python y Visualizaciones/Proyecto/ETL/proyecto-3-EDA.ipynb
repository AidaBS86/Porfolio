# %% [markdown]
# # PROYECTO MÓDULO 3: TRANSFORMANDO EL TALENTO
#
# ### EQUIPO 1
#
# ### ANÁLISIS EXPLORATORIO DE LOS DATOS

# %%
#Importamos las librerías necesarias:

import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from numpy import random

# %%
# Cargamos el csv con todos los datos necesarios:

df_hr = pd.read_csv("HR RAW DATA.csv", index_col=0)
df_hr.sample(4)
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 281   53        No  travel_rarely   1436,0$                    Sales
# 1237  37        No            NaN      nan$   Research & Development
# 1581  32        No            NaN    929,0$                       NaN
# 1195  34        No            NaN    216,0$                       NaN
#
#       DistanceFromHome  Education EducationField  employeecount  \
# 281                  6          2      Marketing              1
# 1237               -24          2  Life Sciences              1
# 1581                10          3      Marketing              1
# 1195               -46          4            NaN              1
#
#      employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 281           205,0                        2       0         34
# 1237            NaN                        2       0         73
# 1581          722,0                        4       0         55
# ...

# %%
# Creamos una función básica para hacer un Análisis Exploratorio de los Datos:

def eda_basico (df):
    print('Filas iniciales:')
    display(df.head(3))
    print('----------------------------------------------------------------------------------')
    print('Filas finales:')
    display(df.tail(3))
    print('----------------------------------------------------------------------------------')    
    print('Filas aleatorias:')
    display(df.sample(3))
    print('----------------------------------------------------------------------------------')
    print('Número de filas:')
    display(df.shape[0])
    print('----------------------------------------------------------------------------------')
    print('Número de columnas:')
    display(df.shape[1])
    print('----------------------------------------------------------------------------------')
    print('Información dataframe:')
    display(df.info())
    print('----------------------------------------------------------------------------------')
    print('Nombre de las columnas:')
    display(df.columns)
    print('----------------------------------------------------------------------------------')
    print('Descripción datos númericos:')
    display(df.describe().T)
    print('----------------------------------------------------------------------------------')
    print('Descripción datos string')
    display(df.describe(include='object').T)
    print('----------------------------------------------------------------------------------')
    print('Cuantos datos únicos hay por columna:')
    display(df.nunique())
    print('----------------------------------------------------------------------------------')
    for col in df.columns:
        print(f'Datos unicos de la {col}:\n {df[col].value_counts()}\n')
    print('----------------------------------------------------------------------------------')
    print('Cuantos datos nulos hay:')
    display(df.isnull().sum())
    print('----------------------------------------------------------------------------------')
    print('Filas duplicadas:')
    cantid_duplicadas = df.duplicated().sum()
    print(f'Cantidad de duplicados: {cantid_duplicadas}')
    if cantid_duplicadas >0:
        print('Primeros duplicados:')
        display(df[df.duplicated()].head(3))
    else:
        print('No hay duplicados')
    print('------------------------------------------------------------------------------------')
    print('Columnas constantes (solo 1 valor único):')
    constantes = df.columns[df.nunique() <= 1]
    if len(constantes) > 0:
        print(f'{len(constantes)} columnas con 1 valor único:')
        display(constantes)
    else:
        print('No hay columnas constantes')

# %%
# Aplicamos la función a nuestro DataFrame y así obtenemos información básica de nuestros datos:

eda_basico(df_hr)
# Out:
# Filas iniciales:
#   Age Attrition BusinessTravel DailyRate                Department  \
# 0  51        No            NaN    684,0$                       NaN
# 1  52        No            NaN    699,0$                       NaN
# 2  42        No  travel_rarely    532,0$   Research & Development
#
#    DistanceFromHome  Education    EducationField  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
#
#   employeenumber  EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  \
# 0          162,0                        1       0         51               3
# 1          259,0                        3       0         65               2
# 2          319,0                        3       0         58               3
#
#    JobLevel              JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# ...
